# %%
import torch
import torch.nn as nn

# %%
# 必须使用 float 类型
x = torch.randint(1, 10, (10,), dtype=torch.float32)

# %%
# 定义一个Dropout层
dropout = nn.Dropout(p=0.5)

# %%
y = dropout(x)

# %%
print(x)
print(y)
# Out:
# tensor([1., 9., 6., 6., 4., 1., 7., 1., 4., 2.])
# tensor([ 0., 18.,  0., 12.,  0.,  2.,  0.,  2.,  0.,  0.])
