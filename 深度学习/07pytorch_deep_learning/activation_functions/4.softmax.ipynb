# %%
import torch

# %%
x = torch.randn(3, 5)
print(x)
# Out:
# tensor([[ 0.7965, -1.2579,  0.0231,  0.4133, -0.3694],
#         [ 1.2697, -1.8230, -0.8380,  0.7552, -0.2473],
#         [ 0.7127, -1.1537, -0.1248, -0.1885,  0.9466]])

# %%
y = torch.softmax(x, dim=1)
print(y)
# Out:
# tensor([[0.3872, 0.0496, 0.1787, 0.2639, 0.1207],
#         [0.5040, 0.0229, 0.0612, 0.3013, 0.1106],
#         [0.3070, 0.0475, 0.1329, 0.1247, 0.3879]])
