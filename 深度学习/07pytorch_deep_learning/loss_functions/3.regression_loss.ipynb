# %%
import torch
import torch.nn as nn

# %%
# 定义数据
input = torch.randn(3, 5)
target = torch.randn(3, 5)
print(input)
print(target)
# Out:
# tensor([[-1.7237,  0.0852, -0.4435, -0.9949,  0.8715],
#         [-1.4807,  0.0186, -0.0334, -0.6238, -0.2919],
#         [-0.8616,  1.6715,  1.2415, -0.7446, -0.9254]])
# tensor([[-0.7088, -1.1107, -0.8607,  0.4671, -0.7627],
#         [-0.0171,  0.8991,  0.4131, -0.8752,  0.2133],
#         [-1.0533, -0.2639,  0.4612,  0.0757, -0.3153]])

# %%
# MSE: L2 Loss
mse_loss = nn.MSELoss()
print(mse_loss(input, target))
# Out:
# tensor(1.0876)

# %%
# MAE: L1 Loss
mse_loss = nn.L1Loss()
print(mse_loss(input, target))
# Out:
# tensor(0.9073)

# %%
# Smooth L1
smooth_l1_loss = nn.SmoothL1Loss()
print(smooth_l1_loss(input, target))
# Out:
# tensor(0.4857)
