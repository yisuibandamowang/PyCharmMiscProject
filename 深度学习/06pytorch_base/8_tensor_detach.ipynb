# %%
import torch

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x.detach()
print(x)
print(y)
# Out:
# tensor(2., requires_grad=True)
# tensor(2.)

# %%
print(x.requires_grad)
print(y.requires_grad)
# Out:
# True
# False

# %%
print(id(x))
print(id(y))
# Out:
# 4388688576
# 4388473888

# %%
print(x.untyped_storage().data_ptr())
print(y.untyped_storage().data_ptr())
# Out:
# 4805314176
# 4805314176

# %%
# print(x)
# y.zero_()
# print(x)

# %%
# 分别对x、y进行后续计算
z1 = x ** 2
z2 = y ** 2
print(z1)
print(z2)
# Out:
# tensor(4., grad_fn=<PowBackward0>)
# tensor(4.)

# %%
print(z1.requires_grad)
print(z2.requires_grad)
# Out:
# True
# False

# %%
z1.sum().backward()

# %%
# z2.sum().backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 z2.sum().backward()
#
# File ~/PyCharmMiscProject/.venv/lib/python3.9/site-packages/torch/_tensor.py:647, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     637 if has_torch_function_unary(self):
#     638     return handle_torch_function(
#     639         Tensor.backward,
#     640         (self,),
#    (...)
#     645         inputs=inputs,
#     646     )
# --> 647 torch.autograd.backward(
#     648     self, gradient, retain_graph, create_graph, inputs=inputs
#     649 )
#
# File ~/PyCharmMiscProject/.venv/lib/python3.9/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File ~/PyCharmMiscProject/.venv/lib/python3.9/site-packages/torch/autograd/graph.py:829, in _engine_run_backward(t_outputs, *args, **kwargs)
#     827     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     828 try:
# --> 829     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     830         t_outputs, *args, **kwargs
#     831     )  # Calls into the C++ engine to run the backward pass
#     832 finally:
#     833     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
x = torch.ones(2, 2, requires_grad=True)
y = x * x
print(x)
print(y)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
# tensor([[1., 1.],
#         [1., 1.]], grad_fn=<MulBackward0>)

# %%
# 分离y
u = y.detach()
print(u)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
# 让u参与新张量的计算
z = u * x

# %%
# 反向传播，计算所有梯度
z.sum().backward()

# %%
print(x.grad)
# Out:
# tensor([[1., 1.],
#         [1., 1.]])

# %%
print(x.grad == u)
# Out:
# tensor([[True, True],
#         [True, True]])
