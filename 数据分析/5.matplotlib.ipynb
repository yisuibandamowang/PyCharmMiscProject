# %%
#折线图
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.lines import lineStyles
from pyparsing import alphas

rcParams['font.family'] = 'STHeiti'

# %%
plt.figure(figsize=(10,5))
month = ['1月','2月','3月','4月']
sales = [100,200,80,400]
plt.plot(month,sales,label = 'chanpinA',marker = 'o',color = 'red',linewidth = 2)
plt.title('销售趋势',color = 'red')
plt.xlabel('月份')
plt.ylabel('销售额')
plt.legend(loc = 'upper left')

plt.grid(True,alpha = 0.2,linestyle = '--')
plt.ylim(0,500)

for x,y in zip(month,sales):
    plt.text(x,y,y,ha = 'center',va = 'bottom')

plt.show()

# %%
#条形图
import matplotlib.pyplot as plt
from matplotlib import rcParams

rcParams['font.family'] = 'STHeiti'
plt.figure(figsize=(10, 5))
# month = ['1月', '2月', '3月', '4月']
# sales = [100, 200, 80, 400]
# plt.plot(month, sales, label='chanpinA', marker='o', color='red', linewidth=2)
# plt.title('销售趋势', color='red')
# plt.xlabel('月份')
# plt.ylabel('销售额')
# plt.legend(loc='upper left')
#
# plt.grid(True, alpha=0.2, linestyle='--')
# plt.ylim(0, 500)
#
# for x, y in zip(month, sales):
#     plt.text(x, y, y, ha='center', va='bottom')

subjects = ['Chinese','Math','English','Physics']
scores = [85,92,78,59]

plt.bar(subjects,scores,color = 'blue',alpha = 0.5,label = '小红')

plt.title('考试成绩',color = 'red')
plt.xlabel('科目')
plt.ylabel('分数')
plt.legend(loc = 'upper left')
plt.grid(axis='y',alpha = 0.3,linestyle = '--')
plt.ylim(0,100)

for x, y in zip(subjects, scores):
    plt.text(x, y, y, ha='center', va='bottom')

plt.tight_layout()
plt.show()
